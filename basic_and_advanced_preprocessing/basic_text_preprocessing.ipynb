# %% [markdown]
# ### Basic Text Preprocessing:

# %% [markdown]
# IN NLP
# 1. data gathering
# 2. Data cleaning
# <!-- 3. EDA  -->
# 3. Text preprocessing
#  - Basic text preprocessing techniques:
#     - Tokenization
#     - Stop word removal
#     - Stemming and Lemmatization
#     - Lowercasing
# - Advanced text preprocessing techniques:
#     - Handling negations
#     - Handling contractions
#     - Handling special characters and punctuation
#     - Handling numbers
#     - Handling URLs and email addresses
#     - Handling emojis and emoticons (demojizer)

# %%
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
# Out:
# ['I am going to delhi',
#  ' I will be there by 5 PM',
#  " Let's meet at the cafe",
#  '']

# %%
# Out:
# ['Hi', 'i', 'am', 'in', 'delhi']

# %%
## Regex Expression

# %%
## . ! ?

# %%
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
# Out:
# ['Hey how are you ', ' I am Fine ', ' I was something for you', '']

# %%
# Out:
# 'run'

# %%
# Out:
# 'good'

# %%
# Out:
# 'mouse'
